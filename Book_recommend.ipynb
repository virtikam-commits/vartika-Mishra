# %% [markdown]
# <a href="https://colab.research.google.com/github/virtikam-commits/vartika-Mishra/blob/main/Book_recommend.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Cell 7
import pandas as pd

books = pd.DataFrame({
    "title": [
        "Harry Potter and the Sorcerer's Stone",
        "Harry Potter and the Chamber of Secrets",
        "The Hobbit",
        "The Lord of the Rings",
        "The Da Vinci Code",
        "Angels and Demons",
        "Pride and Prejudice",
        "Wuthering Heights",

        "ham sath sath hai .",
        "halt CA",
        "3idote ",
        "12fail"
    ],
    "description": [
        "A young wizard begins his magical journey.",
        "Harry Potter returns for his second year at Hogwarts.",
        "A hobbit embarks on an unexpected journey.",
        "A fellowship sets out to destroy the One Ring.",
        "A symbologist uncovers a secret society and mysteries.",
        "A professor races to stop a conspiracy against the Vatican.",
        "A romantic novel about manners and relationships.",
        "A story of love and revenge set on the Yorkshire moors.",


        "family movie",
        "esme 4 brother ek sath rahte hai family bhut khush rahiti pyar ko btaya gya hai .",
        "famlily and education se related .",
        "hard working study " # Added a description for the last book
    ]
})
books
# Out:
#                                       title  \
# 0     Harry Potter and the Sorcerer's Stone
# 1   Harry Potter and the Chamber of Secrets
# 2                                The Hobbit
# 3                     The Lord of the Rings
# 4                         The Da Vinci Code
# 5                         Angels and Demons
# 6                       Pride and Prejudice
# 7                         Wuthering Heights
# 8                       ham sath sath hai .
# 9                                   halt CA
# 10                                  3idote
# 11                                   12fail
#
#                                           description
# 0          A young wizard begins his magical journey.
# 1   Harry Potter returns for his second year at Ho...
# 2          A hobbit embarks on an unexpected journey.
# 3      A fellowship sets out to destroy the One Ring.
# 4   A symbologist uncovers a secret society and my...
# 5   A professor races to stop a conspiracy against...
# ...

# %%
# Cell 8
tfidf_books = TfidfVectorizer(stop_words="english")
tfidf_matrix_books = tfidf_books.fit_transform(books["description"])
cosine_sim_books = cosine_similarity(tfidf_matrix_books, tfidf_matrix_books)

# %%
# Cell 9
def recommend_book(title, num=3):
    if title not in books['title'].values:
        return "Book not found!"

    idx = books[books["title"] == title].index[0]
    sim_scores = list(enumerate(cosine_sim_books[idx]))
    sim_scores = sorted(sim_scores, key=lambda x: x[1], reverse=True)
    sim_scores = sim_scores[1:num+1]
    book_indices = [i[0] for i in sim_scores]
    return books["title"].iloc[book_indices]

# %%
# Cell 10
# Cell 10
recommend_book("Harry Potter and the Sorcerer's Stone", 3)
# Out:
# 2                                 The Hobbit
# 1    Harry Potter and the Chamber of Secrets
# 3                      The Lord of the Rings
# Name: title, dtype: object
